# %% [markdown]
# # Data Screening (Simplified)

# %%
import pandas as pd

files = {
    'Aptitude': 'data/student_aptitude_data.csv',
    'Performance': 'data/student_performance_data.csv',
    'Combined': 'data/student_combined_data.csv'
}

for name, path in files.items():
    df = pd.read_csv(path)
    print(f"[{name}] Shape: {df.shape} | Missing: {df.isnull().sum().sum()}")
    display(df.head(3))
    print("-" * 30)
